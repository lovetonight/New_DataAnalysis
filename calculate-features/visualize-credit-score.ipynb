# %%
from pymongo import MongoClient
import matplotlib.pyplot as plt
import numpy as np
import json

# %%
connection_url = f"mongodb://klgReaderHoan:klg_reader_hoan_123@35.198.222.97:27017,34.124.133.164:27017,34.124.205.24:27017"
connection = MongoClient(connection_url)
lending_knowledge_graph = connection["knowledge_graph"]
wallet_attributes = lending_knowledge_graph["multichain_wallets_credit_scores_v3"]

# %%
wallet_connection = MongoClient("mongodb://localhost:27017/")
data_db = wallet_connection["data-analysis"]
wallet_collection = data_db["wallet"]
wallet_objects = wallet_collection.find()

wallet_liquidate = []
for obj in wallet_objects:
    wallet_liquidate.append(obj.get("address"))

with open(
    "D:/Project/Data-Analysis/New_DataAnalysis/data/whale/whale_740.json", "r"
) as f:
    wallet_addresses_740 = json.load(f)
with open(
    "D:/Project/Data-Analysis/New_DataAnalysis/data/whale/whale_800.json", "r"
) as f:
    wallet_addresses_800 = json.load(f)

# %%
list_name = [
        "x11",
        "x12",
        "x21",
        "x22",
        "x23",
        "x24",
        "x31",
        "x32",
        "x41",
        "x42",
        "x43",
        "x51",
        "x52",
        "x61",
        "x71",
        "x72",
    ]

# %%
def visualize(wallet_addresses):
    ###
    x11 = []
    x12 = []
    x21 = []
    x22 = []
    x23 = []
    x24 = []
    x31 = []
    x32 = []
    x41 = []
    x42 = []
    x43 = []
    x51 = []
    x52 = []
    x61 = []
    x71 = []
    x72 = []

    filter_criteria = {"_id": {"$in": wallet_addresses}}
    objects = wallet_attributes.find(filter_criteria)
    print(f"Số lượng kết quả: {objects.count()}")

    ###
    for obj in objects:
        x1 = obj.get("creditScorex1")
        x2 = obj.get("creditScorex2")
        x3 = obj.get("creditScorex3")
        x4 = obj.get("creditScorex4")
        x5 = obj.get("creditScorex5")
        x6 = obj.get("creditScorex6")
        x7 = obj.get("creditScorex7")
        x11.append(x1[0])
        x12.append(x1[1])
        x21.append(x2[0])
        x22.append(x2[1])
        x23.append(x2[2])
        x24.append(x2[3])
        x31.append(x3[0])
        x32.append(x3[1])
        x41.append(x4[0])
        x42.append(x4[1])
        x43.append(x4[2])
        x51.append(x5[0])
        x52.append(x5[1])
        x61.append(x6[0])
        x71.append(x7[0])
        x72.append(x7[1])
    list_pramater = [
        x11,
        x12,
        x21,
        x22,
        x23,
        x24,
        x31,
        x32,
        x41,
        x42,
        x43,
        x51,
        x52,
        x61,
        x71,
        x72,
    ]
    for x, name in zip(list_pramater,list_name):
        unique_values = np.unique(x)
        if len(unique_values) == 1:
            plt.hist(x, bins=50, color='blue')
            plt.title('Phân bố giá trị của mảng')
            plt.xlabel(f'Giá trị {name}')
            plt.ylabel('Số lượng')
            plt.grid(True)
            plt.locator_params(axis='y', integer=True)  
            plt.show() 
        else:
            plt.hist(x, bins=50, color='blue')
            plt.title('Phân bố giá trị của mảng')
            plt.xlabel(f'Giá trị {name}')
            plt.ylabel('Số lượng')
            plt.grid(True)
            plt.xlim(-10, 900) 
            plt.locator_params(axis='y', integer=True)  
            plt.show()

# %%
visualize(wallet_liquidate)
# Out:
# C:\Users\Dao Trong Hoan\AppData\Local\Temp\ipykernel_22700\269360212.py:22: DeprecationWarning: count is deprecated. Use Collection.count_documents instead.
#   print(f"Số lượng kết quả: {objects.count()}")
# Số lượng kết quả: 152

# %%
visualize(wallet_addresses_740)
# Out:
# C:\Users\Dao Trong Hoan\AppData\Local\Temp\ipykernel_22700\269360212.py:22: DeprecationWarning: count is deprecated. Use Collection.count_documents instead.
#   print(f"Số lượng kết quả: {objects.count()}")
# Số lượng kết quả: 42

# %%
visualize(wallet_addresses_800)
# Out:
# C:\Users\Dao Trong Hoan\AppData\Local\Temp\ipykernel_22700\269360212.py:22: DeprecationWarning: count is deprecated. Use Collection.count_documents instead.
#   print(f"Số lượng kết quả: {objects.count()}")
# Số lượng kết quả: 3196
